# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
from keras.optimizers import Adam, RMSprop, SGD
from keras import regularizers
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
import datetime
import matplotlib.pyplot as plt
from keras.utils import plot_model

# %%
train_dir = r"C:\Users\Vaibhav\Documents\Projects\Facial Emotion recognition\train" #passing the path with training images
test_dir = r"C:\Users\Vaibhav\Documents\Projects\Facial Emotion recognition\test"   #passing the path with testing images

# %%
img_size = 48 #original size of the image

# %%
train_datagen = ImageDataGenerator(#rotation_range = 180,
                                         width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         horizontal_flip = True,
                                         rescale = 1./255,
                                         #zoom_range = 0.2,
                                         validation_split = 0.2
                                        )
validation_datagen = ImageDataGenerator(rescale = 1./255,
                                         validation_split = 0.2)

# %%
train_generator = train_datagen.flow_from_directory(directory = train_dir,
                                                    target_size = (img_size,img_size),
                                                    batch_size = 64,
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical",
                                                    subset = "training"
                                                   )
validation_generator = validation_datagen.flow_from_directory( directory = test_dir,
                                                              target_size = (img_size,img_size),
                                                              batch_size = 64,
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical",
                                                              subset = "validation"
                                                             )
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
model= tf.keras.models.Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(48, 48,1)))
model.add(Conv2D(64,(3,3), padding='same', activation='relu' ))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(5,5), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
    
model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten()) 
model.add(Dense(256,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
    
model.add(Dense(512,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(7, activation='softmax'))

model.compile(
    optimizer = Adam(lr=0.0001), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
  )

# %%
epochs = 60
batch_size = 64

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 48, 48, 32)        320
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 24, 24, 128)       204928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 12, 12, 512)       590336
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 12, 12, 512)       2048
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 4,496,903
# Trainable params: 4,492,935
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
history = model.fit(x = train_generator,epochs = epochs,validation_data = validation_generator)
# Out:
# Epoch 1/60
# 359/359 [==============================] - 910s 3s/step - loss: 9.2867 - accuracy: 0.1962 - val_loss: 9.0963 - val_accuracy: 0.1739
# Epoch 2/60
# 359/359 [==============================] - 811s 2s/step - loss: 8.2604 - accuracy: 0.2301 - val_loss: 7.7284 - val_accuracy: 0.2730
# Epoch 3/60
# 359/359 [==============================] - 4213s 12s/step - loss: 7.2681 - accuracy: 0.2581 - val_loss: 6.6932 - val_accuracy: 0.2870
# Epoch 4/60
# 359/359 [==============================] - 833s 2s/step - loss: 6.3154 - accuracy: 0.2807 - val_loss: 5.7428 - val_accuracy: 0.3233
# Epoch 5/60
# 359/359 [==============================] - 847s 2s/step - loss: 5.4363 - accuracy: 0.3124 - val_loss: 4.8721 - val_accuracy: 0.3736
# Epoch 6/60
# 359/359 [==============================] - 880s 2s/step - loss: 4.6649 - accuracy: 0.3484 - val_loss: 4.1505 - val_accuracy: 0.4001
# Epoch 7/60
# 359/359 [==============================] - 858s 2s/step - loss: 4.0331 - accuracy: 0.3655 - val_loss: 3.5685 - val_accuracy: 0.4323
# Epoch 8/60
# 359/359 [==============================] - 814s 2s/step - loss: 3.5416 - accuracy: 0.3849 - val_loss: 3.2465 - val_accuracy: 0.4148
# Epoch 9/60
# 359/359 [==============================] - 836s 2s/step - loss: 3.1147 - accuracy: 0.4164 - val_loss: 2.7655 - val_accuracy: 0.4937
# Epoch 10/60
# 359/359 [==============================] - 884s 2s/step - loss: 2.7834 - accuracy: 0.4353 - val_loss: 2.6087 - val_accuracy: 0.4651
# Epoch 11/60
# 359/359 [==============================] - 863s 2s/step - loss: 2.5158 - accuracy: 0.4603 - val_loss: 2.2540 - val_accuracy: 0.5182
# Epoch 12/60
# 359/359 [==============================] - 873s 2s/step - loss: 2.2928 - accuracy: 0.4806 - val_loss: 2.0986 - val_accuracy: 0.5279
# Epoch 13/60
# 359/359 [==============================] - 856s 2s/step - loss: 2.1302 - accuracy: 0.4931 - val_loss: 2.0296 - val_accuracy: 0.5286
# Epoch 14/60
# 359/359 [==============================] - 835s 2s/step - loss: 1.9957 - accuracy: 0.5051 - val_loss: 1.8358 - val_accuracy: 0.5601
# Epoch 15/60
# 359/359 [==============================] - 870s 2s/step - loss: 1.8851 - accuracy: 0.5183 - val_loss: 1.7283 - val_accuracy: 0.5817
# Epoch 16/60
# 359/359 [==============================] - 873s 2s/step - loss: 1.7982 - accuracy: 0.5271 - val_loss: 1.7762 - val_accuracy: 0.5461
# Epoch 17/60
# 359/359 [==============================] - 1029s 3s/step - loss: 1.7398 - accuracy: 0.5342 - val_loss: 1.6154 - val_accuracy: 0.5908
# Epoch 18/60
# 359/359 [==============================] - 1170s 3s/step - loss: 1.6881 - accuracy: 0.5452 - val_loss: 1.5902 - val_accuracy: 0.5999
# Epoch 19/60
# 359/359 [==============================] - 1297s 4s/step - loss: 1.6281 - accuracy: 0.5550 - val_loss: 1.4810 - val_accuracy: 0.6096
# Epoch 20/60
# 359/359 [==============================] - 2887s 8s/step - loss: 1.5902 - accuracy: 0.5598 - val_loss: 1.5461 - val_accuracy: 0.5845
# Epoch 21/60
# 359/359 [==============================] - 1194s 3s/step - loss: 1.5620 - accuracy: 0.5681 - val_loss: 1.4950 - val_accuracy: 0.5978
# Epoch 22/60
# 359/359 [==============================] - 1198s 3s/step - loss: 1.5294 - accuracy: 0.5771 - val_loss: 1.4415 - val_accuracy: 0.6152
# Epoch 23/60
# 359/359 [==============================] - 906s 3s/step - loss: 1.5082 - accuracy: 0.5825 - val_loss: 1.4121 - val_accuracy: 0.6180
# Epoch 24/60
# 359/359 [==============================] - 860s 2s/step - loss: 1.4933 - accuracy: 0.5833 - val_loss: 1.4446 - val_accuracy: 0.6159
# Epoch 25/60
# 359/359 [==============================] - 880s 2s/step - loss: 1.4652 - accuracy: 0.5937 - val_loss: 1.3910 - val_accuracy: 0.6194
# Epoch 26/60
# 359/359 [==============================] - 878s 2s/step - loss: 1.4575 - accuracy: 0.5946 - val_loss: 1.4425 - val_accuracy: 0.6020
# Epoch 27/60
# 359/359 [==============================] - 858s 2s/step - loss: 1.4375 - accuracy: 0.6024 - val_loss: 1.4397 - val_accuracy: 0.6152
# Epoch 28/60
# 359/359 [==============================] - 856s 2s/step - loss: 1.4316 - accuracy: 0.6039 - val_loss: 1.3946 - val_accuracy: 0.6334
# Epoch 29/60
# 359/359 [==============================] - 955s 3s/step - loss: 1.4248 - accuracy: 0.6090 - val_loss: 1.3651 - val_accuracy: 0.6453
# Epoch 30/60
# 359/359 [==============================] - 1352s 4s/step - loss: 1.4126 - accuracy: 0.6115 - val_loss: 1.4026 - val_accuracy: 0.6208
# Epoch 31/60
# 359/359 [==============================] - 858s 2s/step - loss: 1.4024 - accuracy: 0.6168 - val_loss: 1.3774 - val_accuracy: 0.6411
# Epoch 32/60
# 359/359 [==============================] - 868s 2s/step - loss: 1.4001 - accuracy: 0.6190 - val_loss: 1.3670 - val_accuracy: 0.6320
# Epoch 33/60
# 359/359 [==============================] - 895s 2s/step - loss: 1.3891 - accuracy: 0.6226 - val_loss: 1.3524 - val_accuracy: 0.6397
# Epoch 34/60
# 359/359 [==============================] - 935s 3s/step - loss: 1.3862 - accuracy: 0.6230 - val_loss: 1.3666 - val_accuracy: 0.6341
# Epoch 35/60
# 359/359 [==============================] - 846s 2s/step - loss: 1.3823 - accuracy: 0.6255 - val_loss: 1.3490 - val_accuracy: 0.6439
# Epoch 36/60
# 359/359 [==============================] - 5520s 15s/step - loss: 1.3777 - accuracy: 0.6298 - val_loss: 1.3314 - val_accuracy: 0.6508
# Epoch 37/60
# 359/359 [==============================] - 852s 2s/step - loss: 1.3682 - accuracy: 0.6333 - val_loss: 1.3405 - val_accuracy: 0.6453
# Epoch 38/60
# 359/359 [==============================] - 22375s 62s/step - loss: 1.3631 - accuracy: 0.6360 - val_loss: 1.3392 - val_accuracy: 0.6522
# Epoch 39/60
# 359/359 [==============================] - 6885s 19s/step - loss: 1.3559 - accuracy: 0.6366 - val_loss: 1.3453 - val_accuracy: 0.6543
# Epoch 40/60
# 359/359 [==============================] - 2232s 6s/step - loss: 1.3474 - accuracy: 0.6426 - val_loss: 1.3084 - val_accuracy: 0.6627
# Epoch 41/60
# 359/359 [==============================] - 1183s 3s/step - loss: 1.3504 - accuracy: 0.6422 - val_loss: 1.3332 - val_accuracy: 0.6557
# Epoch 42/60
# 359/359 [==============================] - 1264s 4s/step - loss: 1.3417 - accuracy: 0.6459 - val_loss: 1.3467 - val_accuracy: 0.6606
# Epoch 43/60
# 359/359 [==============================] - 1185s 3s/step - loss: 1.3440 - accuracy: 0.6469 - val_loss: 1.3731 - val_accuracy: 0.6480
# Epoch 44/60
# 359/359 [==============================] - 1583s 4s/step - loss: 1.3403 - accuracy: 0.6483 - val_loss: 1.3261 - val_accuracy: 0.6613
# Epoch 45/60
# 359/359 [==============================] - 972s 3s/step - loss: 1.3474 - accuracy: 0.6481 - val_loss: 1.4069 - val_accuracy: 0.6348
# Epoch 46/60
# 359/359 [==============================] - 848s 2s/step - loss: 1.3427 - accuracy: 0.6508 - val_loss: 1.3358 - val_accuracy: 0.6620
# Epoch 47/60
# 359/359 [==============================] - 866s 2s/step - loss: 1.3436 - accuracy: 0.6525 - val_loss: 1.3097 - val_accuracy: 0.6676
# Epoch 48/60
# 359/359 [==============================] - 1063s 3s/step - loss: 1.3360 - accuracy: 0.6569 - val_loss: 1.4028 - val_accuracy: 0.6383
# Epoch 49/60
# 359/359 [==============================] - 1114s 3s/step - loss: 1.3319 - accuracy: 0.6573 - val_loss: 1.3479 - val_accuracy: 0.6613
# Epoch 50/60
# 359/359 [==============================] - 1109s 3s/step - loss: 1.3290 - accuracy: 0.6600 - val_loss: 1.3241 - val_accuracy: 0.6571
# Epoch 51/60
# 359/359 [==============================] - 1036s 3s/step - loss: 1.3274 - accuracy: 0.6615 - val_loss: 1.3686 - val_accuracy: 0.6669
# Epoch 52/60
# 359/359 [==============================] - 879s 2s/step - loss: 1.3237 - accuracy: 0.6657 - val_loss: 1.4344 - val_accuracy: 0.6473
# Epoch 53/60
# 359/359 [==============================] - 872s 2s/step - loss: 1.3401 - accuracy: 0.6614 - val_loss: 1.3613 - val_accuracy: 0.6746
# Epoch 54/60
# 359/359 [==============================] - 871s 2s/step - loss: 1.3266 - accuracy: 0.6641 - val_loss: 1.3620 - val_accuracy: 0.6648
# Epoch 55/60
# 359/359 [==============================] - 870s 2s/step - loss: 1.3222 - accuracy: 0.6667 - val_loss: 1.3313 - val_accuracy: 0.6627
# Epoch 56/60
# 359/359 [==============================] - 869s 2s/step - loss: 1.3188 - accuracy: 0.6679 - val_loss: 1.3176 - val_accuracy: 0.6634
# Epoch 57/60
# 359/359 [==============================] - 955s 3s/step - loss: 1.3130 - accuracy: 0.6751 - val_loss: 1.3560 - val_accuracy: 0.6711
# Epoch 58/60
# 359/359 [==============================] - 1189s 3s/step - loss: 1.3154 - accuracy: 0.6721 - val_loss: 1.3518 - val_accuracy: 0.6648
# Epoch 59/60
# 359/359 [==============================] - 1780s 5s/step - loss: 1.3264 - accuracy: 0.6743 - val_loss: 1.3561 - val_accuracy: 0.6739
# Epoch 60/60
# 359/359 [==============================] - 1166s 3s/step - loss: 1.3149 - accuracy: 0.6750 - val_loss: 1.4074 - val_accuracy: 0.6536

# %%
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
model.save('model_optimal.h5')

# %%
from PIL import Image, ImageOps

# %%
img = Image.open(r"C:\Users\Vaibhav\Documents\Projects\Facial Emotion recognition\train\happy\Training_355217.jpg")#,target_size = (48,48),color_mode = "grayscale")
img.resize((48,48))
ImageOps.grayscale(img)
img = np.array(img)
plt.imshow(img)
print(img.shape) #prints (48,48) that is the shape of our image
# Out:
# (48, 48)

# %%
label_dict = {0:'Angry',1:'Disgust',2:'Fear',3:'Happy',4:'Neutral',5:'Sad',6:'Surprise'}

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(1,2,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(validation_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 359/359 [==============================] - 208s 581ms/step - loss: 1.2699 - accuracy: 0.6952
# 23/23 [==============================] - 12s 534ms/step - loss: 1.4074 - accuracy: 0.6536
# final train accuracy = 69.52 , validation accuracy = 65.36

# %%
y_pred = model.predict(train_generator)
y_pred = np.argmax(y_pred, axis=1)
class_labels = validation_generator.class_indices
class_labels = {v:k for k,v in class_labels.items()}

from sklearn.metrics import classification_report, confusion_matrix
cm_train = confusion_matrix(train_generator.classes, y_pred)
print('Confusion Matrix')
print(cm_train)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(train_generator.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_train, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# Confusion Matrix
# [[ 338   61  228  939  767  466  397]
#  [  30    7   22  120   77   44   49]
#  [ 323   66  163 1048  802  452  424]
#  [ 540  116  384 1878 1306  843  705]
#  [ 391   66  217 1293  924  574  507]
#  [ 382   64  226 1247  940  526  479]
#  [ 239   56  184  810  573  380  295]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.15      0.11      0.12      3196
#      disgust       0.02      0.02      0.02       349
#         fear       0.11      0.05      0.07      3278
#        happy       0.26      0.33      0.29      5772
#      neutral       0.17      0.23      0.20      3972
#          sad       0.16      0.14      0.15      3864
#     surprise       0.10      0.12      0.11      2537
#
#     accuracy                           0.18     22968
#    macro avg       0.14      0.14      0.14     22968
# weighted avg       0.17      0.18      0.17     22968

# %%
model.save_weights('model_weights.h5')
